# %%
pip install tweepy

# %%
import tweepy

client = tweepy.Client(bearer_token="AAAAAAAAAAAAAAAAAAAAAC7H2gEAAAAAjemZ8yTCnkTZCBLjylS6r0ypKtY%3DOTMdKwLTVGjFsAWN284p2qyM3g2uc8cZgRJEoTC7PVrmIZ9mg7")

# Get tweets about airlines (e.g., 'American Airlines')
tweets = client.search_recent_tweets(query="American Airlines -is:retweet lang:en", max_results=10)

for tweet in tweets.data:
    print(tweet.text)
# Out:
# American Airlines Pilot Reports UFO With ''Big Reflection'' 40,000 Feet Over Arizona. “Something just passed over u
# Beautiful woman I don't know what to do
# . Do I worship her or allow American airlines to falter due to her sexy body and beautiful self https://t.co/L3JCWUhOZT
# @benniehimself Very true.. now airlines charge you for selecting a seat. oh and American Airlines sets itself apart. For business class, you have to bring your own TV (smartphone, tablet, etc) with the stream to your device. Give me a break
# i don’t recall a good experience i’ve had flying american airlines and it’s my own fault each time i subject myself to flying such a bottom of the barrel fucking airline
# Yeah cool I’m here, 6 hours later. Why is my suitcase full of water American Airlines did you drench our luggage after the captain walked off https://t.co/N9jl56ZJeB
# ...
